# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/LDS8_K270_ONLINE_DoThiPhuong/LDS8_K270_DoThiPhuong_Cuoi_ky/Cau_3/'
# Out:
# /content/gdrive/My Drive/LDS8_K270_ONLINE_DoThiPhuong/LDS8_K270_DoThiPhuong_Cuoi_ky/Cau_3

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Part 3 - Making new predictions
from tensorflow.keras.models import load_model
classifier = load_model('my_model_CNN_lion_tiger.h5')

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# %%
test_image = image.load_img('dataset/single_prediction/lion_or_tiger_1.jpg',
                            target_size = (64,64))
test_image = image.img_to_array(test_image)
print(test_image.shape)
test_image = test_image/255
test_image = np.expand_dims(test_image, axis = 0)
print(test_image.shape)

result = classifier.predict(test_image)
print(result)

# 0: cat, 1: dog, sigmoid có ngưỡng 0.5
if result[0][0] >= 0.5:
  prediction = 'tiger'
else:
  prediction = 'lion'
print(prediction)
# Out:
# (64, 64, 3)
# (1, 64, 64, 3)
# [[0.27180976]]
# lion

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('dataset/single_prediction/lion_or_tiger_1.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
test_image = image.load_img('dataset/single_prediction/lion_or_tiger_11.jpg', 
                            target_size = (64, 64))
test_image = image.img_to_array(test_image)
print(test_image.shape)
test_image = test_image/255
test_image = np.expand_dims(test_image, axis = 0)
print(test_image.shape)
result = classifier.predict(test_image)
print(result)

if result[0][0] > 0.5:
    prediction = 'tiger'
else:
    prediction = 'lion'
print(prediction)
# Out:
# (64, 64, 3)
# (1, 64, 64, 3)
# [[0.9999994]]
# tiger

# %%
# %pylab inline
img=mpimg.imread('dataset/single_prediction/lion_or_tiger_11.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
